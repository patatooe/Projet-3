# %%
# imports de nos fonctions (from NOM_DU_FICHIER import NOM_DE_LA_FONCTION)
from methode_matrice_2D import methode_matrice_2D_A
from methode_matrice_2D import methode_matrice_2D_b
from methode_matrice_2D_temporelle import methode_matrice_2D_temporelle

from calcul_energie_chauffage import calcul_energie_chauffage
from calcul_energie_panneaux import calcul_energie_panneaux
from graph_T import graph_T
from graph_E_vs_p import graph_E_vs_p
from graph_E_vs_taille import graph_E_vs_taille
from graph_E_vs_ptaille import graph_E_vs_ptaille

#import des fonctions externes
import numpy as np
import matplotlib.pyplot as plt
import yaml
from scipy.sparse import csc_matrix
from scipy.sparse.linalg import spsolve
from scipy.optimize import curve_fit
import imageio.v2
import os
import time
from memory_profiler import profile
import psutil
# Out:
# 1361.1664654085753
# 589.1475352357062
# 2625.7069162974067
# 50.33899650179644

# %%
# Define the function to fit
def fit(x, a, b,):
    return a * x**b

def get_memory_usage():
    process = psutil.Process()
    return process.memory_info().rss

#Constantes
with open('constants.yaml') as f:
    planets_constants = yaml.safe_load(f)



p = 3   # Profondeur de l'abris [m]
l_x = l_z = 3 # Largeur de l'abris en x [m] # Hauteur de l'abris en z [m]
Lx = Lz = 10 # Largeur du domaine [m] et  Hauteur du domaine [m]
d = 0.1  # Pas de discrétisation [m]

Nx=int(np.rint(Lx/d+1)) # Nombre de nœuds le long de X
Nz=int(np.rint(Lz/d+1)) # Nombre de nœuds le long de Z

z = np.linspace(0, Lz, Nz)
x= np.linspace(0, Lx, Nx)


d_list = [2, 1,  1/2, 1/4, 1/8, 1/16, 1/32]
t_list = []
mem_list = []
if __name__ == '__main__':
    for i in d_list:
        before_memory = 0
        before_time = time.time_ns()
        methode_matrice_2D_temporelle(planets_constants['earth'], p, l_x, l_z, Lx, Lz, i)
        after_memory = get_memory_usage()
        after_time = time.time_ns()
        peak_time = (after_time-before_time)/1.0e9
        peak_memory = after_memory - before_memory
        t_list.append(peak_time)
        mem_list.append(peak_memory)
        print(f"Peak memory usage: {peak_memory/1024} KB")
        print(f"Time: {peak_time} seconds")
# Out:
#         ##################################################
#          ATTENTION! : CRITÈRE DE CONVERGENCE NON RESPECTÉ
#             dt = 16720.0, alpha*d^2=5400000.0, tau = 83600
#         ##################################################
#  #######################################################################################################
#     DÉBUT DU CALCUL
#     PARAMÈTRES :
#     - Domaine : 10x10 m
#     - Abri : True, 3x3 m
#     - Discrétisation : Pas de 2 m avec 6x6 points
#     - Temps: Évaluation sur 2006400.0 avec un pas de 16720.0 s sur 120 itérations
# --------------------------------------------------------------------------------------------------------
#     Progression :
#  99%|█████████▉| 119/120 [00:18<00:00,  6.54it/s]
#
# CALCUL TERMINÉ : ANIMATION SAUVEGARDÉE
# #######################################################################################################
# Peak memory usage: 163568.0 KB
# Time: 19.2314837 seconds
#
#         ##################################################
#          ATTENTION! : CRITÈRE DE CONVERGENCE NON RESPECTÉ
#             dt = 16720.0, alpha*d^2=1350000.0, tau = 83600
#         ##################################################
#  #######################################################################################################
#     DÉBUT DU CALCUL
#     PARAMÈTRES :
#     - Domaine : 10x10 m
#     - Abri : True, 3x3 m
#     - Discrétisation : Pas de 1 m avec 11x11 points
#     - Temps: Évaluation sur 2006400.0 avec un pas de 16720.0 s sur 120 itérations
# --------------------------------------------------------------------------------------------------------
#     Progression :
#  99%|█████████▉| 119/120 [00:18<00:00,  6.37it/s]
#
# CALCUL TERMINÉ : ANIMATION SAUVEGARDÉE
# #######################################################################################################
# Peak memory usage: 164012.0 KB
# Time: 19.6960516 seconds
#
#         ##################################################
#          ATTENTION! : CRITÈRE DE CONVERGENCE NON RESPECTÉ
#             dt = 16720.0, alpha*d^2=337500.0, tau = 83600
#         ##################################################
#  #######################################################################################################
#     DÉBUT DU CALCUL
#     PARAMÈTRES :
#     - Domaine : 10x10 m
#     - Abri : True, 3x3 m
#     - Discrétisation : Pas de 0.5 m avec 21x21 points
#     - Temps: Évaluation sur 2006400.0 avec un pas de 16720.0 s sur 120 itérations
# --------------------------------------------------------------------------------------------------------
#     Progression :
#  99%|█████████▉| 119/120 [00:20<00:00,  5.94it/s]
#
# CALCUL TERMINÉ : ANIMATION SAUVEGARDÉE
# #######################################################################################################
# Peak memory usage: 163504.0 KB
# Time: 21.0632995 seconds
#
#         ##################################################
#          ATTENTION! : CRITÈRE DE CONVERGENCE NON RESPECTÉ
#             dt = 16720.0, alpha*d^2=84375.0, tau = 83600
#         ##################################################
#  #######################################################################################################
#     DÉBUT DU CALCUL
#     PARAMÈTRES :
#     - Domaine : 10x10 m
#     - Abri : True, 3x3 m
#     - Discrétisation : Pas de 0.25 m avec 41x41 points
#     - Temps: Évaluation sur 2006400.0 avec un pas de 16720.0 s sur 120 itérations
# --------------------------------------------------------------------------------------------------------
#     Progression :
#  99%|█████████▉| 119/120 [00:23<00:00,  5.11it/s]
#
# CALCUL TERMINÉ : ANIMATION SAUVEGARDÉE
# #######################################################################################################
# Peak memory usage: 168116.0 KB
# Time: 24.3845065 seconds
#
#         ##################################################
#          ATTENTION! : CRITÈRE DE CONVERGENCE NON RESPECTÉ
#             dt = 10546.875, alpha*d^2=21093.75, tau = 83600
#         ##################################################
#  #######################################################################################################
#     DÉBUT DU CALCUL
#     PARAMÈTRES :
#     - Domaine : 10x10 m
#     - Abri : True, 3x3 m
#     - Discrétisation : Pas de 0.125 m avec 81x81 points
#     - Temps: Évaluation sur 1265625.0 avec un pas de 10546.875 s sur 120 itérations
# --------------------------------------------------------------------------------------------------------
#     Progression :
#  99%|█████████▉| 119/120 [00:38<00:00,  3.12it/s]
#
# CALCUL TERMINÉ : ANIMATION SAUVEGARDÉE
# #######################################################################################################
# Peak memory usage: 166092.0 KB
# Time: 39.5336116 seconds
#  #######################################################################################################
#     DÉBUT DU CALCUL
#     PARAMÈTRES :
#     - Domaine : 10x10 m
#     - Abri : True, 3x3 m
#     - Discrétisation : Pas de 0.0625 m avec 161x161 points
#     - Temps: Évaluation sur 316406.25 avec un pas de 2636.71875 s sur 120 itérations
# --------------------------------------------------------------------------------------------------------
#     Progression :
#  99%|█████████▉| 119/120 [01:47<00:00,  1.11it/s]
#
# CALCUL TERMINÉ : ANIMATION SAUVEGARDÉE
# #######################################################################################################
# Peak memory usage: 191124.0 KB
# Time: 109.8725407 seconds
#  #######################################################################################################
#     DÉBUT DU CALCUL
#     PARAMÈTRES :
#     - Domaine : 10x10 m
#     - Abri : True, 3x3 m
#     - Discrétisation : Pas de 0.03125 m avec 321x321 points
#     - Temps: Évaluation sur 79101.5625 avec un pas de 659.1796875 s sur 120 itérations
# --------------------------------------------------------------------------------------------------------
#     Progression :
#  99%|█████████▉| 119/120 [07:27<00:03,  3.76s/it]
#
# CALCUL TERMINÉ : ANIMATION SAUVEGARDÉE
# #######################################################################################################
# Peak memory usage: 239604.0 KB
# Time: 454.7384531 seconds

# %%
poptmem, pcov = curve_fit(fit, (d_list), (mem_list))
a_mem, b_mem = poptmem
mem_list_fit = fit(d_list, a_mem, b_mem)

plt.figure(2)    
plt.scatter((d_list), (mem_list))
plt.loglog((d_list), mem_list_fit, label = "fit lineaire: $t_{{ini}} = {a_mem:.2f})\delta^{{{b_mem:.2f}}}$")
plt.legend()
plt.xlabel('pas de discrétisation')
plt.ylabel('mémoire utilisée (kB)')
plt.title('Mémoire utilisée en fonction du pas de discrétisation')
plt.savefig('memoryEval.png')
plt.show()

popt, pcov = curve_fit(fit, (d_list), (t_list))
a_t, b_t = popt
t_list_fit = fit(d_list, a_t, b_t)


plt.figure(3)
plt.scatter((d_list),(t_list))
plt.loglog((d_list), t_list_fit, label = "fit lineaire: $t_{{ini}} = ({a_t:.2e})\delta^{{{b_t:.2f}}}$")
plt.legend()
plt.xlabel('pas de discrétisation (m)')
plt.ylabel('temps de calcul (s)')
plt.title('Temps de calcul en fonction du pas de discrétisation')
plt.savefig('timeEval.png')
plt.show()
